# %% [markdown]
# <a href="https://colab.research.google.com/github/nikhilkalghatgi/learning/blob/main/MNIST_ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
mnist = tf.keras.datasets.mnist

# %%
(X_train, y_train),(X_test, y_test) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
X_train, X_test = X_train/255.0,  X_test/255.0

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(
    optimizer = 'adam',
    loss = 'sparse_categorical_crossentropy',
    metrics = ['accuracy']
)

# %%
r = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.2995 - accuracy: 0.9139 - val_loss: 0.1362 - val_accuracy: 0.9596
# Epoch 2/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1450 - accuracy: 0.9566 - val_loss: 0.0986 - val_accuracy: 0.9697
# Epoch 3/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1081 - accuracy: 0.9670 - val_loss: 0.0920 - val_accuracy: 0.9727
# Epoch 4/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0893 - accuracy: 0.9727 - val_loss: 0.0796 - val_accuracy: 0.9771
# Epoch 5/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0752 - accuracy: 0.9766 - val_loss: 0.0735 - val_accuracy: 0.9753
# Epoch 6/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0647 - accuracy: 0.9798 - val_loss: 0.0717 - val_accuracy: 0.9789
# Epoch 7/10
# ...

# %%
# Plot loss per iteration (epoch)
import matplotlib.pyplot as plt
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
# Plot accuracy 
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val_accuracy')
plt.legend()
